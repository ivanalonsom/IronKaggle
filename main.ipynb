# %%
import pandas as pd

df_ini = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/sales.csv")

df_no_target = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/ironkaggle_notarget.csv")

df_real_data = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/ironkaggle_solutions.csv")

# %%
df_ini
# Out:
#         True_index  Store_ID  Day_of_week        Date  Nb_customers_on_day  \
# 0                0       625            3  2013-11-06                  641
# 1                1       293            2  2013-07-16                  877
# 2                2        39            4  2014-01-23                  561
# 3                3       676            4  2013-09-26                 1584
# 4                4       709            3  2014-01-22                 1477
# ...            ...       ...          ...         ...                  ...
# 640835      712040       674            6  2014-09-20                  611
# 640836      712041      1014            4  2015-01-15                 1267
# 640837      712042       135            6  2015-06-20                  595
# 640838      712043       810            1  2014-08-18                  599
# 640839      712044       592            1  2013-03-18                  798
#
#         Open  Promotion State_holiday  School_holiday  Sales
# ...

# %%
df_no_target
# Out:
#        True_index  Store_ID  Day_of_week        Date  Nb_customers_on_day  \
# 0               7       764            4  2013-12-26                    0
# 1              19        22            3  2013-05-22                  449
# 2              31      1087            6  2013-06-29                  622
# 3              45       139            6  2013-08-17                  314
# 4              56       568            1  2014-04-07                  356
# ...           ...       ...          ...         ...                  ...
# 71200      712004       217            2  2015-01-13                  633
# 71201      712018       604            3  2014-04-30                  743
# 71202      712020      1021            5  2014-07-18                 1852
# 71203      712023        28            3  2014-08-27                    0
# 71204      712027       655            3  2014-12-31                  455
#
#        Open  Promotion State_holiday  School_holiday
# ...

# %%
df_real_data
# Out:
#        True_index         Sales
# 0               7      0.000000
# 1              19   3792.528564
# 2              31   5999.958008
# 3              45   3365.519287
# 4              56   3458.130127
# ...           ...           ...
# 71200      712004   5714.028320
# 71201      712018   9701.739258
# 71202      712020  15175.256836
# 71203      712023      0.000000
# 71204      712027   4220.416504
#
# [71205 rows x 2 columns]
